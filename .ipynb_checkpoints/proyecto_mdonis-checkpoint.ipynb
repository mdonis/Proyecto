# %% [markdown]
# #### Creando la clase principal:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import metrics

class regression():
    # Mapeo de variables que contiene el objeto de tipo npy
    varss = ['SalePrice','OverallQual','1stFlrSF','TotRmsAbvGrd','YearBuilt','LotFrontage']
    d = {'SalePrice':0,'OverallQual':1,'1stFlrSF':2,'TotRmsAbvGrd':3,'YearBuilt':4,'LotFrontage':5}
    # Selección de la variable a predecir
    predictable = d['SalePrice']
    # Diccionario para almacenar coeficientes de correlación
    r = {}
    
    def __init__(self, npy_filename):
        # Carga de set de datos en formato npy
        self.npy = np.load('{}.npy'.format(npy_filename))
        # Para reproducibilidad de los resultados
        np.random.seed(30)
        # Se reordena aleatoreamente el dataset
        np.random.shuffle(self.npy)
        # Se define una variable para hacer slicing al 80%
        s = int(self.npy.shape[0]*0.8)
        self.train = self.npy[0:s,:]
        self.test = self.npy[s:,:]
        
        # Definición de variables dependientes en función de la variable a predecir
        self.y_train = self.train[:,self.predictable].reshape(-1, 1)
        self.y_test = self.test[:,self.predictable].reshape(-1,1)
        
        # Análogos en estructuras de dataframe
        self.df = pd.DataFrame(self.npy, columns = self.varss)
        self.train_df = pd.DataFrame(self.train, columns = self.varss)
        self.test_df = pd.DataFrame(self.test, columns = self.varss)
    
    # Método de análisis exploratorio
    def exp_analysis(self):
        # Se generan las métricas a partir de las columnas de los dataframes
        med = self.df.median(axis = 0)
        maxx = self.df.max(axis = 0)
        minn = self.df.min(axis = 0)
        rang = maxx - minn
        std = self.df.std(axis = 0)
        # Se genera un dataframe como resultado
        result = pd.concat([med,maxx,minn,rang,std], keys = ['median','max','min','range','std'], axis = 1)
        return result
    
    # Método para generar histogramas de todas las variables
    def hist(self):
        # Se genera un histograma a partir de cada variable
        for i in self.df.columns:
            sns.displot(self.df['{}'.format(i)], kde=True)
            plt.show()
    
    # Método para elegir varible (cálculo de correlaciones)
    def vars_select(self):
        # Se pasa por cada variable definiendo 'x' y 'y'
        for i in self.d:
            # Si la variable x no contiene nans, tomar toda la columna
            if np.isnan(self.train[:,self.d[i]].sum()) == False:
                y = self.train[:,self.predictable]
                x = self.train[:,self.d[i]]
                n = y.shape[0]
            # De lo contrario, si la variable contiene nans, tanto 'y' como 'x' se
            # se convierten en sub arreglos sin nans
            else:
                train_nonna = self.train[~np.isnan(self.train).any(axis=1)]
                y = train_nonna[:,self.predictable]
                x = train_nonna[:,self.d[i]]
                n = y.shape[0]
            
            # Cálculo y almacenamiento de los coeficientes de correlación en un diccionario
            self.r['{}'.format(i)] = (n*(x*y).sum() - x.sum()*y.sum()) / ((n*(x**2).sum() - x.sum()**2)*(n*(y**2).sum() - y.sum()**2))**(1/2)
            
            # Gráficas de puntos indicando el las variables y el coeficiente de correlación
            plt.scatter(x, y, s = 0.3)
            plt.title('{} Where r = {}'.format(self.varss[self.d[i]],self.r[i]))
            plt.xlabel(self.varss[self.d[i]])
            plt.ylabel(self.varss[self.predictable])
            plt.show()
        return self.r
    
    # Método para cambiar la variable que se desea predecir
    @classmethod
    def change_var_to_predict(cls, var):
        regression.predictable = regression.d[var]
    
    # Método para generar un modelo con seteo manual de parámetros
    def manual_model(self,x_name,epochs,error_freq,learn_rate):
        # Variable independiente recibida
        self.x_name = x_name
        # Definiendo datos de entrenamiento
        self.x_train = self.train[:,self.d[x_name]].reshape(-1, 1)
        # Generación de matríz para operación vectorizada
        b = np.ones_like(self.x_train)
        self.mat_a = np.hstack([self.x_train,b])
        # Parámetros iniciales
        b1, b0 = 1, 1
        # Número de iteraciones
        self.epochs = epochs
        # Frecuencia de impresión de errores
        self.error_freq = error_freq
        # Learning Rate
        self.learn_rate = learn_rate
        # Tamaño de la muestra
        n = self.y_train.shape[0]
        # Diccionario para almacenar betas
        self.bi = {}
        # Lista que indica las posiciones en las que se imprimen los errores
        err = list(range(0,self.epochs+1,self.error_freq))
        
        # Generación de cada uno de los modelos
        for i in range(self.epochs):
            # Si es la primera iteración utilizar los parámetros iniciales
            if i == 0:
                vect = np.array([[b1],[b0]])
            # Si es una iteración diferente de la primera, utilizar los parámetros de 
            # la iteración anterior
            else:
                vect = self.bi[i-1]
            # Se calcula la predicción utilizando la matriz anteriormente generada y el
            # vector de parámetros
            self.y_train_h_mm = np.matmul(self.mat_a, vect)
            # Cálculo del error del modelo y posterior almacenamiento si corresponde a una
            # iteración imprimible
            e = (1/(2*n))*((self.y_train-self.y_train_h_mm)**2).sum()
            if i in err:
                if i == 0:
                    self.errors = np.array([e])
                else:
                    self.errors = np.append(self.errors,[e])
            # Cálculo vectorizado de las betas de la presente iteración
            mat_b = np.transpose(self.y_train_h_mm-self.y_train)
            b_grad = (np.matmul(mat_b,self.mat_a)/n).reshape(-1,1)
            mat1 = np.hstack([vect,b_grad])
            mat2 = np.array([[1],[-self.learn_rate]])
            self.bi[i] = np.matmul(mat1,mat2)
        
        # Mean Absolute Error (Para comparar con sklearn)
        error = (1/n)*(np.absolute(self.y_train-self.y_train_h_mm)).sum()
        # Gráfica de los errores
        plt.plot(range(1,self.epochs+1,self.error_freq),self.errors)
        plt.title('Model Error')
        plt.xlabel('Iteration')
        plt.ylabel('Error')
        plt.show()
        
        # Gráfica del modelo resultante en la última iteración
        plt.plot(self.x_train, self.y_train_h_mm)
        plt.scatter(self.x_train, self.y_train, s = 0.3)
        plt.title('Model')
        plt.xlabel(x_name)
        plt.ylabel(self.varss[self.predictable])
        plt.show()
        return str('Betas: '), self.bi, str('Errores: '), self.errors, str('Mean Absolute Error: '), error

    # Método para visualizar la evolución del modelo a cada 'n' iteraciones
    def model_evol(self,n):
        self.n = n
        # Modelos a ser graficados
        models = list(range(0,self.epochs,self.n))
        # Se grafica cada uno de los modelos
        for i in models:
            # Si es el último modelo graficarlo en rojo
            if i == self.n*(self.epochs/self.n-1):
                plt.plot(self.x_train,np.matmul(self.mat_a, self.bi[i]), color='r')
            # De lo contrario, graficarlo con color transparente
            else:
                plt.plot(self.x_train,np.matmul(self.mat_a, self.bi[i]), alpha=0.2)
        # Graficar de fondo el scatter plot de los datos
        plt.scatter(self.x_train, self.y_train, s = 0.3)
        plt.title('Model')
        plt.xlabel(self.x_name)
        plt.ylabel(self.varss[self.predictable])
        plt.show()
    
    # Generación de un modelo con sklearn de la variable indicada con el set de datos
    # de entrenamiento
    def sklearn_model(self,x_name):
        # Set de datos de entrenamiento (y ya está definido en __init__)
        self.x_train = self.train[:,self.d[x_name]].reshape(-1,1)
        # Se crea el modelo con los datos de entrenamiento
        self.reg = linear_model.LinearRegression().fit(self.x_train, self.y_train)
        # Cálculo de la predicción con reg.predict
        self.y_train_h_sm = self.reg.predict(self.x_train)
        # Se utiliza el método mean_absolute_error para obtener un parámetro de
        # comparación con el modelo manual
        error = metrics.mean_absolute_error(self.y_train, self.y_train_h_sm)
        # Métodos para obtener parámetros de la regresión sklearn
        b0 = self.reg.intercept_
        b1 = self.reg.coef_
        # Graficación del modelo y el set de datos en un mismo plano
        plt.plot(self.x_train, self.y_train_h_sm)
        plt.scatter(self.x_train, self.y_train, s = 0.3)
        plt.title('Model')
        plt.xlabel(x_name)
        plt.ylabel(self.varss[self.predictable])
        plt.show()
        return str('b0'), b0, str('b1'), b1, str('Error'), error
    
    # Método para realizar una estimación promedidada entre ambos modelos
    def both_models(self,x_name,number_of_y_predictions):
        x = number_of_y_predictions
        # Subset de las predicciones en función del vector recibido
        y_h_mm_subset = self.y_train_h_mm[0:x,]
        y_h_sm_subset = self.y_train_h_sm[0:x,]
        # Cálculo del promedio de las predicciones
        mean = (y_h_mm_subset + y_h_sm_subset)/2
        return str('manual model'),y_h_mm_subset, str('sklearn model'),y_h_sm_subset, str('mean_prediction'),mean
    
    # Método para comparar el error de ambos modelos (utilizando el set de pruebas)
    def test_models(self,x_name):
        # Se genera la variable de prueba
        self.x_test = self.test[:,self.d[x_name]].reshape(-1,1)
        # Cálculo de la predicción con el modelo sklearn
        y_test_h_sm = self.reg.predict(self.x_test)
        # Error del modelo sklearn
        error_sm = metrics.mean_absolute_error(self.y_test, y_test_h_sm)
        
        # Procedimiento para calcular la predicción del modelo manual
        # Matríz de la variable
        b = np.ones_like(self.x_test)
        mat_a = np.hstack([self.x_test,b])
        # Vector de betas (de la última iteración)
        vect = self.bi[self.epochs-1]
        # Cálculo de la predicción
        y_test_h_mm = np.matmul(mat_a, vect)
        # Cálculo del error
        error_mm = metrics.mean_absolute_error(self.y_test, y_test_h_mm)
        
        # Gráfico de barras para ambos errores
        d = {'sklearn model': error_sm, 'manual model': error_mm}
        df = pd.DataFrame(d, index=[0])
        values = df.values.flatten()
        sns.barplot(x = df.columns,y=values).set_title('{} prediction errors'.format(x_name))
        plt.show()
        return str('{} sklearn error: '.format(x_name)),error_sm, str('{} manual error: '.format(x_name)), error_mm

# %% [markdown]
# #### Creación de un objeto en la clase:

# %%
obj = regression('proyecto_training_data')

# %% [markdown]
# #### Realizando análisis exploratiorio:

# %%
obj.exp_analysis()
# Out:
#                 median       max      min     range           std
# SalePrice     163000.0  755000.0  34900.0  720100.0  79442.502883
# OverallQual        6.0      10.0      1.0       9.0      1.382997
# 1stFlrSF        1087.0    4692.0    334.0    4358.0    386.587738
# TotRmsAbvGrd       6.0      14.0      2.0      12.0      1.625393
# YearBuilt       1973.0    2010.0   1872.0     138.0     30.202904
# LotFrontage       69.0     313.0     21.0     292.0     24.284752

# %% [markdown]
# #### Generación de histogramas:

# %%
obj.hist()

# %% [markdown]
# #### Selección de la variable con mejor correlación:

# %%
obj.vars_select()
# Out:
# {'SalePrice': 1.0,
#  'OverallQual': 0.7852601840571318,
#  '1stFlrSF': 0.6062581268012549,
#  'TotRmsAbvGrd': 0.5205783232896812,
#  'YearBuilt': 0.5184584108863033,
#  'LotFrontage': 0.3534555777664909}

# %% [markdown]
# #### Generación de un modelo manual para la variable con la mejor correlación:

# %%
obj.manual_model('OverallQual', 200, 10, 0.049)
# Out:
# ('Betas: ',
#  {0: array([[58312.35916267],
#          [ 8873.63770462]]),
#   1: array([[2386.7227387 ],
#          [-103.56066026]]),
#   2: array([[56163.88807099],
#          [ 8061.68848875]]),
#   3: array([[4592.15232375],
#          [-234.06912536]]),
#   4: array([[54187.89003858],
#          [ 7278.90866482]]),
#   5: array([[6631.29147536],
#          [-388.34772966]]),
#   6: array([[52370.92120404],
#          [ 6523.18718697]]),
#   7: array([[8517.05356105],
#          [-564.38897879]]),
#   8: array([[50700.58380821],
#          [ 5792.57651888]]),
#   9: array([[10261.34735117],
#          [ -760.34230623]]),
#   10: array([[49165.4448026 ],
#          [ 5085.27991553]]),
#   11: array([[11875.15518011],
#          [ -974.50186021]]),
#   12: array([[47754.96079047],
#          [ 4399.63969444]]),
#   13: array([[13368.6050262 ],
#          [-1205.29524091]]),
#   14: array([[46459.40880783],
#          [ 3734.12641947]]),
#   15: array([[14751.03698358],
# ...

# %% [markdown]
# #### Evolución del modelo en cada iteración (1):

# %%
obj.model_evol(1)

# %% [markdown]
# #### Creación de un modelo con sklearn:

# %%
obj.sklearn_model('OverallQual')
# Out:
# ('b0',
#  array([-95351.08549477]),
#  'b1',
#  array([[45353.71061355]]),
#  'Error',
#  34289.270593176785)

# %% [markdown]
# #### Estimación promedio:

# %%
obj.both_models('OverallQual',3)
# Out:
# ('manual model',
#  array([[180752.95810668],
#         [180752.95810668],
#         [145207.2403299 ]]),
#  'sklearn model',
#  array([[176771.17818655],
#         [176771.17818655],
#         [131417.467573  ]]),
#  'mean_prediction',
#  array([[178762.06814662],
#         [178762.06814662],
#         [138312.35395145]]))

# %% [markdown]
# #### Comparando errores de ambos modelos:

# %%
obj.test_models('OverallQual')
# Out:
# ('OverallQual sklearn error: ',
#  31499.97914375167,
#  'OverallQual manual error: ',
#  32925.016418745516)

# %% [markdown]
# #### Consulta de variable que se desea predecir:

# %%
regression.varss[regression.predictable]
# Out:
# 'SalePrice'

# %% [markdown]
# #### Asignando una nueva variable para predecir:

# %%
regression.change_var_to_predict('OverallQual')
regression.varss[regression.predictable]
# Out:
# 'OverallQual'

# %% [markdown]
# #### Creando un segundo objeto con los ajustes anteriores:

# %%
obj2 = regression('proyecto_training_data')

# %% [markdown]
# #### Se desea saber cuáles variables presentan mejores correlaciones con la que se quiere predecir:

# %%
obj2.vars_select()
# Out:
# {'SalePrice': 0.7852601840571318,
#  'OverallQual': 1.0,
#  '1stFlrSF': 0.4725291937315773,
#  'TotRmsAbvGrd': 0.41132780805016445,
#  'YearBuilt': 0.5760924160122115,
#  'LotFrontage': 0.27009475407819145}

# %% [markdown]
# #### Se genera un modelo para predecir con la variable seleccionada:

# %%
obj2.manual_model('YearBuilt', 200, 10, 0.00000001)
# Out:
# ('Betas: ',
#  {0: array([[0.96123351],
#          [0.99998034]]),
#   1: array([[0.92397376],
#          [0.99996144]]),
#   2: array([[0.88816219],
#          [0.99994328]]),
#   3: array([[0.85374252],
#          [0.99992582]]),
#   4: array([[0.82066064],
#          [0.99990904]]),
#   5: array([[0.78886456],
#          [0.99989292]]),
#   6: array([[0.75830431],
#          [0.99987742]]),
#   7: array([[0.72893185],
#          [0.99986252]]),
#   8: array([[0.70070101],
#          [0.9998482 ]]),
#   9: array([[0.67356742],
#          [0.99983444]]),
#   10: array([[0.64748845],
#          [0.99982121]]),
#   11: array([[0.62242308],
#          [0.9998085 ]]),
#   12: array([[0.59833194],
#          [0.99979628]]),
#   13: array([[0.57517715],
#          [0.99978454]]),
#   14: array([[0.55292232],
#          [0.99977325]]),
#   15: array([[0.53153248],
#          [0.9997624 ]]),
#   16: array([[0.510974  ],
#          [0.99975198]]),
#   17: array([[0.49121457],
# ...

# %% [markdown]
# #### Evolución del modelo en cada iteración (1):

# %%
obj2.model_evol(1)

# %% [markdown]
# #### Ahora se genera el modelo con sklearn:

# %%
obj2.sklearn_model('YearBuilt')
# Out:
# ('b0',
#  array([-45.55264742]),
#  'b1',
#  array([[0.02620058]]),
#  'Error',
#  0.8636017635145461)

# %% [markdown]
# #### Predicción promedio:

# %%
obj2.both_models('YearBuilt',3)
# Out:
# ('manual model',
#  array([[6.80388134],
#         [6.80388134],
#         [6.80388134]]),
#  'sklearn model',
#  array([[5.74807852],
#         [5.74807852],
#         [5.74807852]]),
#  'mean_prediction',
#  array([[6.27597993],
#         [6.27597993],
#         [6.27597993]]))

# %% [markdown]
# #### Comparando errores:

# %%
obj2.test_models('YearBuilt')
# Out:
# ('YearBuilt sklearn error: ',
#  0.8708366951945318,
#  'YearBuilt manual error: ',
#  1.2505784401038385)
